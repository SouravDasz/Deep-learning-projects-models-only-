# %% [markdown]
# <a href="https://colab.research.google.com/github/SouravDasz/Deep-learning-projects-models-only-/blob/main/optuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.datasets import load_iris

# %%
data=load_iris()

# %%
x=data.data

# %%
y=data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
! pip install optuna
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 7.3 MB/s eta 0:00:00
# ...

# %%
import optuna

# %%
def objective(trail):
  n_estimator=trail.suggest_int("n_estimator",10,200)
  max_depth=trail.suggest_int("max_depth",3,10)
  model=RandomForestClassifier(
      n_estimators=n_estimator,
      max_depth=max_depth
  )
  score=cross_val_score(model,x_train,y_train,cv=3,scoring="accuracy").mean()
  return score

# %%
study=optuna.create_study(direction="maximize",sampler=optuna.samplers.TPESampler())
# Out:
# [I 2026-03-15 09:28:02,554] A new study created in memory with name: no-name-9ae3ae3c-e550-470a-bd96-208d44eb4b2f

# %%
study.optimize(objective,n_trials=20)
# Out:
# [I 2026-03-15 09:28:51,766] Trial 0 finished with value: 0.9500000000000001 and parameters: {'n_estimator': 112, 'max_depth': 9}. Best is trial 0 with value: 0.9500000000000001.
# [I 2026-03-15 09:28:51,972] Trial 1 finished with value: 0.9583333333333334 and parameters: {'n_estimator': 66, 'max_depth': 6}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-03-15 09:28:52,199] Trial 2 finished with value: 0.9500000000000001 and parameters: {'n_estimator': 66, 'max_depth': 4}. Best is trial 1 with value: 0.9583333333333334.
# [I 2026-03-15 09:28:52,632] Trial 3 finished with value: 0.9666666666666667 and parameters: {'n_estimator': 144, 'max_depth': 5}. Best is trial 3 with value: 0.9666666666666667.
# [I 2026-03-15 09:28:52,870] Trial 4 finished with value: 0.9500000000000001 and parameters: {'n_estimator': 75, 'max_depth': 6}. Best is trial 3 with value: 0.9666666666666667.
# ...

# %%
study.best_params
# Out:
# {'n_estimator': 144, 'max_depth': 5}

# %%
study.best_value
# Out:
# 0.9666666666666667

# %%
from optuna.visualization import plot_optimization_history,plot_parallel_coordinate,plot_slice,plot_contour,plot_param_importances

# %%
plot_param_importances(study).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_slice(study).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_contour(study).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_optimization_history(study).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_parallel_coordinate(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
study.trials_dataframe()
# Out:
#     number     value  ... params_n_estimator     state
# 0        0  0.950000  ...                112  COMPLETE
# 1        1  0.958333  ...                 66  COMPLETE
# 2        2  0.950000  ...                 66  COMPLETE
# 3        3  0.966667  ...                144  COMPLETE
# 4        4  0.950000  ...                 75  COMPLETE
# 5        5  0.950000  ...                 54  COMPLETE
# 6        6  0.966667  ...                197  COMPLETE
# 7        7  0.941667  ...                 31  COMPLETE
# 8        8  0.950000  ...                 15  COMPLETE
# 9        9  0.958333  ...                 56  COMPLETE
# 10      10  0.950000  ...                149  COMPLETE
# 11      11  0.958333  ...                187  COMPLETE
# 12      12  0.950000  ...                200  COMPLETE
# 13      13  0.950000  ...                156  COMPLETE
# 14      14  0.950000  ...                162  COMPLETE
# 15      15  0.958333  ...                120  COMPLETE
# ...
